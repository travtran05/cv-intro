# %%
import cv2
from matplotlib import pyplot as plt
import lane_detection
import lane_following

# %%
IP_ADDRESS = "192.168.1.102"

# %%
vcap = cv2.VideoCapture(f"rtsp://{IP_ADDRESS}:8554/rovcam")

img = None

MAX_RETRY = 100
count = 0
while count < MAX_RETRY:
    count += 1
    # Obtain the frame
    ret, frame = vcap.read()

    # Check frame was received successfully
    if ret:
        # got a frame, close the cap and return the frame
        img = frame
        vcap.release()

vcap.release()

# %%
img = cv2.imread('classLane.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
lines = lane_detection.detect_lines(img)
lanes = lane_detection.detect_lanes(lines)
center, slope = lane_following.get_lane_center(lanes)
print(lane_following.recommend_direction(center, slope))
lane_detection.draw_lines(img, lines)
lane_detection.draw_lanes(img, lanes)
#lane_detection.draw_Single_lane(img, lanes)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 lines = lane_detection.detect_lines(img)
#       2 lanes = lane_detection.detect_lanes(lines)
#       3 center, slope = lane_following.get_lane_center(lanes)
#
# NameError: name 'img' is not defined
